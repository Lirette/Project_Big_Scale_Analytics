# %% [markdown]
# <a href="https://colab.research.google.com/github/Rolex-Github/Team_Rolex_BigScale/blob/main/Notebook/Final_project%20(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # big-scale analytics 2022 - Team Rolex
#
# ### HEC Lausanne - Prof. Michalis Vlachos, Diana Korka, Ahmad Ajalloeian
#
# ![](https://raw.githubusercontent.com/Rolex-Github/Team_Rolex_BigScale/main/Notebook/Images/Capture_projet1.PNG)
#
#
# ## Final Notebook

# %% [markdown]
# * [Click here ](https://github.com/Rolex-Github/Team_Rolex_BigScale) to open our githup repo
# * Callable API point which, given a text in French, will return its difficulty : [here](https://french-text-difficulty-350020.lm.r.appspot.com/)

# %% [markdown]
# ### To obtain those result what we did was the following:
# Fist of all we have upload the training dataset in autoML then we made the training.
# The results of the training was the following:

# %% [markdown]
# a. What is the
# * accuracy  : **0,503**
# * various metrics :
#   * precision : **0,58**
#   * recall:**0,32**

# %% [markdown]
# ## Here below there are screenshots were you can get more information

# %% [markdown]
# ![](https://raw.githubusercontent.com/Rolex-Github/Team_Rolex_BigScale/main/Notebook/Images/Capture1.PNG)
# ## Confision metrics
# ![](https://raw.githubusercontent.com/Rolex-Github/Team_Rolex_BigScale/main/Notebook/Images/Capture2.PNG)

# %% [markdown]
# ### in order to have a better metrics, we added data in our data set. We have also removed some which the level was not appropriate.
# the results that we obtain was a little bit better

# %% [markdown]
# ## the new result was the following:
# * accuracy  : **0,56**   the previous was 0,503
# * various metrics :
#   * precision : **0,597**  the previous was 0,58
#   * recall:**0,399**     the previous was 0,32
#
#
#   Here you can have a look

# %% [markdown]
# ![](https://raw.githubusercontent.com/Rolex-Github/Team_Rolex_BigScale/main/Notebook/Images/Capture3_projet.PNG)
# ## Confision metrics
# ![](https://raw.githubusercontent.com/Rolex-Github/Team_Rolex_BigScale/main/Notebook/Images/Capture2_projet.PNG)

# %% [markdown]
# ## To deploy  our application, we created a service account and also the key. then we received the following JSON file

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##with the Json file and the flask file that we have created, we have been able to deploy our application locally. the result was the following

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## then we have dockerize our application and deploy it on the cloud. some files and folder has been added in our project folder as:
# * Docker
# * requirements.txt
# * app.yaml
# * template folder(containing the home page and the result)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
